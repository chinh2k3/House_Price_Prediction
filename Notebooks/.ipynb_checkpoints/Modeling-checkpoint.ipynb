# %% [markdown]
# # 1.Library Imports

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.pipeline import Pipeline

try:
    import lightgbm as lgb
    HAS_LGB = True
    print("LightGBM available")
except ImportError:
    HAS_LGB = False
    print("lightgbm not installed — skip LightGBM section")

sns.set_style('whitegrid')
plt.rcParams['figure.dpi'] = 100
RANDOM_STATE = 42
# Out:
# lightgbm not installed — skip LightGBM section

# %% [markdown]
# # 2.Data Loading

# %%
BASE_DIR = Path.cwd().parent
DATA_PATH = BASE_DIR / "Data" / "processed" / "preprocessed.csv"
csv_data = pd.read_csv(DATA_PATH)
csv_data.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  LotShape  LandSlope  OverallQual  \
# 0          60         65.0     8450         4          3            7
# 1          20         80.0     9600         4          3            6
# 2          60         68.0    11250         3          3            7
# 3          70         60.0     9550         3          3            7
# 4          60         84.0    14260         3          3            8
#
#    OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  ...  HouseAge  \
# 0            5       2003          2003       196.0  ...         5
# 1            8       1976          1976         0.0  ...        31
# 2            5       2001          2002       162.0  ...         7
# 3            5       1915          1970         0.0  ...        91
# 4            5       2000          2000       350.0  ...         8
#
#    YearsSinceRemod  Remodeled  TotalArea  HasLotFrontage  LogGrLivArea  \
# 0                5          0     4824.0               1      7.444833
# 1               31          0     4246.0               1      7.141245
# 2                6          1     5100.0               1      7.488294
# 3               36          1     4832.0               1      7.448916
# 4                8          0     6377.0               1      7.695758
#
#    LogTotalArea  LogLotArea  QualArea  SalePrice
# 0      8.481566    9.042040     11970     208500
# 1      8.353968    9.169623      7572     181500
# 2      8.537192    9.328212     12502     223500
# 3      8.483223    9.164401     12019     140000
# 4      8.760610    9.565284     17584     250000
#
# [5 rows x 235 columns]

# %% [markdown]
# # 3.Target Analysis and Log transform

# %%
df = csv_data.copy()
X = df.drop("SalePrice", axis=1)
y = df["SalePrice"]

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
sns.histplot(y, kde=True, ax=axes[0])
axes[0].set_title(f'SalePrice  (skew={y.skew():.3f})')

# Logarit SalePrice
y_log = np.log1p(y)
sns.histplot(y_log, kde=True, ax=axes[1], color='orange')
axes[1].set_title(f'log(SalePrice)  (skew={y_log.skew():.3f})')
plt.tight_layout()
plt.show()

# %%
# 
print(f"SalePrice skewness: {y.skew():.3f}")
print(f"log(SalePrice) skewness: {y_log.skew():.3f}")
print("Training models on log(SalePrice)")
# Out:
# SalePrice skewness: 1.883
# log(SalePrice) skewness: 0.121
# Training models on log(SalePrice)

# %% [markdown]
# # 4.Train/Test Split

# %%
X_train, X_test, y_train_log, y_test_log = train_test_split(X, y_log, test_size=0.2, random_state=RANDOM_STATE)

# Keep raw y for metric reporting
y_train_raw = np.expm1(y_train_log)
y_test_raw  = np.expm1(y_test_log)

# %%
print(f"X_train: {X_train.shape}  |  X_test: {X_test.shape}")
print(f"y_train_raw range: [{y_train_raw.min():.0f}, {y_train_raw.max():.0f}]")
print(f"y_test_raw  range: [{y_test_raw.min():.0f},  {y_test_raw.max():.0f}]")
# Out:
# X_train: (1168, 234)  |  X_test: (292, 234)
# y_train_raw range: [34900, 745000]
# y_test_raw  range: [35311,  755000]

# %% [markdown]
# # 5.Preprocessing - StanderdScaler

# %%
num_cols  = X_train.select_dtypes(include=[np.number]).columns
flag_cols = [c for c in num_cols if c.endswith('_was_missing') or c.endswith('_nonzero')]
scale_cols = [c for c in num_cols if c not in flag_cols]

# %%
print(f"Total numeric cols: {len(num_cols)}")
print(f"Flag cols (skip): {len(flag_cols)}")
print(f"Cols to scale: {len(scale_cols)}")
# Out:
# Total numeric cols: 234
# Flag cols (skip): 30
# Cols to scale: 204

# %%
X_train = X_train.copy()
X_test  = X_test.copy()

# %%
# force data to float type
X_train[scale_cols] = X_train[scale_cols].astype(float)
X_test[scale_cols]  = X_test[scale_cols].astype(float)

# %%
# Standardization
scaler = StandardScaler()
# With training, it will fit_transform
X_train.loc[:, scale_cols] = scaler.fit_transform(X_train[scale_cols])
X_test.loc[:, scale_cols]  = scaler.transform(X_test[scale_cols])

# %%
# Sanity check
assert X_train.select_dtypes(include='object').empty, "Still has object columns!"
print("Scaling done. Train mean (sample):",
      X_train[scale_cols].mean().abs().max(), "(≈ 0)")
# Out:
# Scaling done. Train mean (sample): 6.596853961115177e-14 (≈ 0)

# %% [markdown]
# # 6. Evaluate Helper Funtion

# %%
# evaluate funtion
def evaluate(model, X_tr, X_te, y_tr_raw, y_te_raw, name = 'Model'):
    y_tr_pred = np.expm1(np.clip(model.predict(X_tr),0, 15))
    y_te_pred = np.expm1(np.clip(model.predict(X_te),0, 15))

    
    def _metrics(y_true, y_pred, label):
        r2   = r2_score(y_true, y_pred)
        mae  = mean_absolute_error(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        rmsle= np.sqrt(mean_squared_error(np.log1p(y_true), np.log1p(np.clip(y_pred, 0, None))))
        print(f"{label:6s}: R²={r2:.4f}, MAE={mae:.0f}, RMSE={rmse:.0f}, RMSLE={rmsle:.4f}")
        return {"r2": r2, "mae": mae, "rmse": rmse, "rmsle": rmsle}

   
    print(f"{name}")
    tr = _metrics(y_tr_raw, y_tr_pred, "Train")
    te = _metrics(y_te_raw, y_te_pred, "Test ")
    gap = tr["r2"] - te["r2"]
    if gap > 0.05:
        print(f"Overfit gap: {gap:.4f}")
    return te, y_te_pred

# %%
# Plot actual and predict, residual
def plot_results(y_true, y_pred, title):
    """Plot Actual vs Predicted and Residual Plot side by side."""
    residuals = y_true - y_pred
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Actual vs Predicted
    axes[0].scatter(y_true, y_pred, alpha=0.4, s=20)
    lo, hi = y_true.min(), y_true.max()
    axes[0].plot([lo, hi], [lo, hi], 'r--', lw=2)
    axes[0].set_xlabel('Actual Price')
    axes[0].set_ylabel('Predicted Price')
    axes[0].set_title(f'Actual vs Predicted — {title}')

    # Residual
    axes[1].scatter(y_pred, residuals, alpha=0.4, s=20)
    axes[1].axhline(0, color='gray', linestyle='--')
    axes[1].set_xlabel('Predicted Price')
    axes[1].set_ylabel('Residual (Actual − Predicted)')
    axes[1].set_title(f'Residual Plot — {title}')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 7. Baseline LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train_log)

print(f"Max |coef|: {np.max(np.abs(lr.coef_)):.4f}")
print(f"Intercept: {lr.intercept_:.4f}")

lr_metrics, _ = evaluate(lr, X_train, X_test, y_train_raw, y_test_raw, 'LinearRegression')
# Out:
# Max |coef|: 83835973639.6602
# Intercept: -3210408800.2685
# LinearRegression
# Train : R²=0.9492, MAE=11239, RMSE=17406, RMSLE=0.0892
# Test  : R²=-7.2557, MAE=37274, RMSE=251643, RMSLE=0.7541
# Overfit gap: 8.2049

# %% [markdown]
# # 8. Ridge(Alpha = 1.0)

# %%
ridge_base = Ridge(alpha=1.0)
ridge_base.fit(X_train, y_train_log)

print(f"Max |coef|: {np.max(np.abs(ridge_base.coef_)):.4f}")
print(f"Intercept: {ridge_base.intercept_:.4f}")
# Out:
# Max |coef|: 0.1965
# Intercept: 12.0680

# %%
ridge_base_metrics, y_ridge_pred = evaluate(ridge_base, X_train, X_test, y_train_raw, y_test_raw, 'Ridge(alpha=1.0)')
plot_results(y_test_raw, y_ridge_pred, 'Ridge alpha=1.0')
# Out:
# Ridge(alpha=1.0)
# Train : R²=0.9482, MAE=11225, RMSE=17569, RMSLE=0.0906
# Test  : R²=0.9150, MAE=14558, RMSE=25534, RMSLE=0.1274

# %% [markdown]
# # 9. Cross-Validation Comparison (Ridge / Lasso / ElasticNet)

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

models_cv = {
    'Ridge(1.0)': Ridge(alpha=1.0),
    'Lasso(0.001)': Lasso(alpha=0.001, max_iter=5000),
    'ElasticNet(0.001)': ElasticNet(alpha=0.001, l1_ratio=0.5, max_iter=5000),
}

print(f"{'Model':<25}  CV R² (mean ± std)")
for name, model in models_cv.items():
    scores = cross_val_score(model, X_train, y_train_log, cv=kf, scoring='r2', n_jobs=-1)
    print(f"{name:<25}  {scores.mean():.4f} ± {scores.std():.4f}")
# Out:
# Model                      CV R² (mean ± std)
# Ridge(1.0)                 0.8866 ± 0.0082
# Lasso(0.001)               0.8881 ± 0.0241
# ElasticNet(0.001)          0.8852 ± 0.0226

# %% [markdown]
# # 10. GridSearch - Ridge

# %%
alphas = np.logspace(-3, 3, 30)
ridge_as = Ridge()
grid_ridge = GridSearchCV(ridge_as, param_grid = {'alpha': alphas}, cv = kf, scoring = 'r2', n_jobs = -1)
grid_ridge.fit(X_train, y_train_log)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Ridge(), n_jobs=-1,
#              param_grid={'alpha': array([1.00000000e-03, 1.61026203e-03, 2.59294380e-03, 4.17531894e-03,
#        6.72335754e-03, 1.08263673e-02, 1.74332882e-02, 2.80721620e-02,
#        4.52035366e-02, 7.27895384e-02, 1.17210230e-01, 1.88739182e-01,
#        3.03919538e-01, 4.89390092e-01, 7.88046282e-01, 1.26896100e+00,
#        2.04335972e+00, 3.29034456e+00, 5.29831691e+00, 8.53167852e+00,
#        1.37382380e+01, 2.21221629e+01, 3.56224789e+01, 5.73615251e+01,
#        9.23670857e+01, 1.48735211e+02, 2.39502662e+02, 3.85662042e+02,
#        6.21016942e+02, 1.00000000e+03])},
#              scoring='r2')

# %%
print(f"Best alpha: {grid_ridge.best_params_['alpha']:.4f}")
print(f"Best CV R²: {grid_ridge.best_score_:.4f}")
# Out:
# Best alpha: 2.0434
# Best CV R²: 0.8878

# %%
# Plot CV score vs alpha
cv_results = pd.DataFrame(grid_ridge.cv_results_)
plt.figure(figsize=(8, 4))
plt.semilogx(cv_results['param_alpha'].astype(float), cv_results['mean_test_score'], marker='o')
plt.axvline(grid_ridge.best_params_['alpha'], color='red', linestyle='--', label=f"Best alpha={grid_ridge.best_params_['alpha']:.3f}")
plt.xlabel('Alpha (log scale)')
plt.ylabel('CV R²')
plt.title('Ridge — GridSearchCV: alpha vs CV R²')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # 11. GridSearch Lasso

# %%
lasso_alphas = np.logspace(-4, 0, 40)
grid_lasso = GridSearchCV(Lasso(max_iter = 10000), param_grid = {'alpha': lasso_alphas}, cv = kf, scoring = 'r2', n_jobs = -1)
grid_lasso.fit(X_train, y_train_log)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Lasso(max_iter=10000), n_jobs=-1,
#              param_grid={'alpha': array([1.00000000e-04, 1.26638017e-04, 1.60371874e-04, 2.03091762e-04,
#        2.57191381e-04, 3.25702066e-04, 4.12462638e-04, 5.22334507e-04,
#        6.61474064e-04, 8.37677640e-04, 1.06081836e-03, 1.34339933e-03,
#        1.70125428e-03, 2.15443469e-03, 2.728333...
#        4.37547938e-03, 5.54102033e-03, 7.01703829e-03, 8.88623816e-03,
#        1.12533558e-02, 1.42510267e-02, 1.80472177e-02, 2.28546386e-02,
#        2.89426612e-02, 3.66524124e-02, 4.64158883e-02, 5.87801607e-02,
#        7.44380301e-02, 9.42668455e-02, 1.19377664e-01, 1.51177507e-01,
#        1.91448198e-01, 2.42446202e-01, 3.07029063e-01, 3.88815518e-01,
#        4.92388263e-01, 6.23550734e-01, 7.89652287e-01, 1.00000000e+00])},
#              scoring='r2')

# %%
print(f"Best alpha: {grid_lasso.best_params_['alpha']:.6f}")
print(f"Best CV R²: {grid_lasso.best_score_:.4f}")
# Out:
# Best alpha: 0.003455
# Best CV R²: 0.8929

# %%
best_lasso = grid_lasso.best_estimator_
n_zero = np.sum(best_lasso.coef_ == 0)
print(f"Features zeroed out: {n_zero} / {len(best_lasso.coef_)} (Lasso feature selection)")
# Out:
# Features zeroed out: 144 / 234 (Lasso feature selection)

# %% [markdown]
# # 12 Final Model Compasion

# %%
best_ridge = grid_ridge.best_estimator_
best_lasso = grid_lasso.best_estimator_

results = {}
final_model = {'LinearRegression': lr,'Ridge (best)': best_ridge,'Lasso (best)': best_lasso}
for name, model in final_model.items():
    metrics, _ = evaluate(model, X_train, X_test, y_train_raw, y_test_raw, name)
    results[name] = metrics

comparison_df = pd.DataFrame(results).T.round(4)
print("\n--- Test Set Summary ---")
print(comparison_df.to_string())
# Out:
# LinearRegression
# Train : R²=0.9492, MAE=11239, RMSE=17406, RMSLE=0.0892
# Test  : R²=-7.2557, MAE=37274, RMSE=251643, RMSLE=0.7541
# Overfit gap: 8.2049
# Ridge (best)
# Train : R²=0.9469, MAE=11285, RMSE=17790, RMSLE=0.0911
# Test  : R²=0.9167, MAE=14519, RMSE=25278, RMSLE=0.1303
# Lasso (best)
# Train : R²=0.9037, MAE=13251, RMSE=23961, RMSLE=0.1082
# Test  : R²=0.9126, MAE=14619, RMSE=25896, RMSLE=0.1331
#
# --- Test Set Summary ---
#                       r2         mae         rmse   rmsle
# LinearRegression -7.2557  37273.6966  251642.6296  0.7541
# Ridge (best)      0.9167  14519.2727   25277.9512  0.1303
# Lasso (best)      0.9126  14619.1373   25895.9373  0.1331

# %%
# Bar char competion
fig, axes = plt.subplots(1, 3, figsize = (14,4))
metrics_to_plot = ['r2', 'mae', 'rmse']
for i, metric in enumerate(metrics_to_plot):
    comparison_df[metric].plot(kind = 'bar', ax = axes[i],color=['#e74c3c', '#3498db', '#2ecc71'])
    axes[i].set_title(metric.upper())
    axes[i].set_xticklabels(comparison_df.index, rotation=20, ha='right')
    axes[i].set_xlabel('')
plt.suptitle('Test Set — Model Comparison', fontsize=13, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 13. Best Ridge Model

# %%
_, y_best_pred = evaluate(best_ridge, X_train, X_test, y_train_raw, y_test_raw, 'Best Ridge (final)')
plot_results(y_test_raw, y_best_pred, 'Best Ridge')
# Out:
# Best Ridge (final)
# Train : R²=0.9469, MAE=11285, RMSE=17790, RMSLE=0.0911
# Test  : R²=0.9167, MAE=14519, RMSE=25278, RMSLE=0.1303

# %%
# KDE: Actual vs Predicted
plt.figure(figsize=(8, 5))
sns.kdeplot(y_test_raw, label='Actual', fill=True, color='steelblue', alpha=0.6)
sns.kdeplot(y_best_pred, label='Predicted', fill=True, color='coral', alpha=0.6)
plt.xlabel('House Price')
plt.ylabel('Density')
plt.title('KDE: Actual vs Predicted (Best Ridge)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Residual distribution
residuals = y_test_raw - y_best_pred
plt.figure(figsize=(7, 4))
sns.histplot(residuals, kde=True, bins=40)
plt.axvline(0, color='red', linestyle='--')
plt.xlabel('Residual (Actual − Predicted)')
plt.title('Residual Distribution (Best Ridge)')
plt.tight_layout()
plt.show()

print(f"Residual mean  : {residuals.mean():,.0f}")
print(f"Residual std   : {residuals.std():,.0f}")
print(f"Residual median: {np.median(residuals):,.0f}")
# Out:
# Residual mean  : 1,898
# Residual std   : 25,250
# Residual median: 1,081

# %%
# Top 15 most influential features
coef_series = pd.Series(best_ridge.coef_, index=X_train.columns)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
coef_series.nlargest(15).plot(kind='barh', ax=axes[0], color='steelblue')
axes[0].set_title('Top 15 Positive Coefficients (Best Ridge)')

coef_series.nsmallest(15).plot(kind='barh', ax=axes[1], color='coral')
axes[1].set_title('Top 15 Negative Coefficients (Best Ridge)')

plt.tight_layout()
plt.show()
